# %% [markdown]
# # Assignment
# ---
# Instructions:<br>
# 1. Create a folder in your github account titled Intro_Vectors.<br>
# 2. Use Jupyterhub notebook to answer the problems.<br>
# 3. Rename Jupyter notebook to Intro_Vectors.ipynb.<br>
# 4. Show both manual and pythonic solutions.<br>
# 5. For manual solutions write it in Latex format.<br>

# %% [markdown]
# 1. Let $\textbf{u} = (1, -2, 4)$ and $\textbf{v} = (3,5,1)$ $\textbf{w} = (2,1,-3)$ find:<br>
# a. $3\textbf{u}-2\textbf{v}$<br>
# b. $5\textbf{u}+3\textbf{v}-4\textbf{w}$<br>
# c. $\textbf{u} \cdotp \textbf{v}$,$\textbf{v} \cdotp \textbf{w}$, $\textbf{u} \cdotp \textbf{w}$<br>
# d. ||$\textbf{u}||, ||$\textbf{v}||, ||$\textbf{w}$||<br>
# e. If $\theta$ is the angle between $\textbf{u}$  and   $\textbf{v}$, find $\cos{\theta}$.<br>
# f. If $\alpha$ is the angle between $\textbf{v}$  and   $\textbf{w}$, find $\cos{\alpha}$.<br>
# g. If $\beta$ is the angle between $\textbf{u}$  and   $\textbf{w}$, find $\cos{\beta}$.<br>
# h. Find $d(\textbf{u},\textbf{v})$.<br>
# i. Find $d(\textbf{w},\textbf{v})$.<br>
# j. Find $d(\textbf{u},\textbf{w})$. <br>
# k. Find $proj(\textbf{u},\textbf{v})$.<br>
# l. Find $proj(\textbf{w},\textbf{v})$.<br>
# m. Find $proj(\textbf{u},\textbf{w})$. <br>
# <br>
# <br>

# %%
import numpy as np

def perform_operations():
    u = np.array([1, -2, 4])
    v = np.array([3, 5, 1])
    w = np.array([2, 1, -3])

    # Letter A
    result_a = (3*u) - (2*v)
    print("Letter A - 3𝐮-2v: ", result_a)

    # Letter B
    result_b = (5*u) + (3*v) - (4*w)
    print("Letter B - 5𝐮+3v-4w: ", result_b)

    # Letter C
    print("Letter C - u.v = ", u.dot(v))
    print("Letter C - v.w = ", v.dot(w))
    print("Letter C - u.w = ", u.dot(w))

    # Letter D
    print("Letter D - ||u||: ", np.sqrt(u.dot(u)))
    print("Letter D - ||v||: ", np.sqrt(v.dot(v)))
    print("Letter D - ||w||: ", np.sqrt(w.dot(w)))

    # Letter E
    angle_uv = u.dot(v) / (np.linalg.norm(u) * np.linalg.norm(v))
    print("Letter E - angle(u, v):", angle_uv)

    # Letter F
    angle_vw = v.dot(w) / (np.linalg.norm(v) * np.linalg.norm(w))
    print("Letter F - angle(v, w):", angle_vw)

    # Letter G
    angle_uw = u.dot(w) / (np.linalg.norm(u) * np.linalg.norm(w))
    print("Letter G - angle(u, w):", angle_uw)

    # Letter H
    print("Letter H - d(u, v): ", np.linalg.norm(u - v))

    # Letter I
    print("Letter I - d(w, v): ", np.linalg.norm(w - v))

    # Letter J
    print("Letter J - d(u, w): ", np.linalg.norm(u - w))

    # Letter K
    proj_uv = u.dot(v) * v / (np.linalg.norm(v) ** 2)
    print("Letter K - proj(u, v): ", proj_uv)

    # Letter L
    proj_wv = w.dot(v) * v / (np.linalg.norm(v) ** 2)
    print("Letter L - proj(w, v): ", proj_wv)

    # Letter M
    proj_uw = u.dot(w) * w / (np.linalg.norm(w) ** 2)
    print("Letter M - proj(u, w): ", proj_uw)

# Call the function
perform_operations()
# Out:
# Letter A - 3𝐮-2v:  [ -3 -16  10]
# Letter B - 5𝐮+3v-4w:  [ 6  1 35]
# Letter C - u.v =  -3
# Letter C - v.w =  8
# Letter C - u.w =  -12
# Letter D - ||u||:  4.58257569495584
# Letter D - ||v||:  5.916079783099616
# Letter D - ||w||:  3.7416573867739413
# Letter E - angle(u, v): -0.11065666703449763
# Letter F - angle(v, w): 0.36140316116210053
# Letter G - angle(u, w): -0.6998542122237653
# Letter H - d(u, v):  7.874007874011811
# Letter I - d(w, v):  5.744562646538029
# Letter J - d(u, w):  7.681145747868608
# Letter K - proj(u, v):  [-0.25714286 -0.42857143 -0.08571429]
# Letter L - proj(w, v):  [0.68571429 1.14285714 0.22857143]
# Letter M - proj(u, w):  [-1.71428571 -0.85714286  2.57142857]

# %% [markdown]
# 2. Repeat problem 1 with the following column vectors:
# \begin{align}
#     \textbf{u} &= \begin{bmatrix}
#            1 \\
#            3 \\
#            -4
#          \end{bmatrix}, \textbf{v} = \begin{bmatrix}
#            2 \\
#            1 \\
#            5
#          \end{bmatrix}, \textbf{w} = \begin{bmatrix}
#            3 \\
#            -2 \\
#            6
#          \end{bmatrix}
#   \end{align}
# <br>
# <br>
# <br>

# %%
import numpy as np

def perform_operations():
    u = np.array([1, 3, -4])
    v = np.array([2, 1, 5])
    w = np.array([3, -2, 6])

    # Letter A
    result_a = (3*u) - (2*v)
    print("Letter A - 3𝐮-2v: ", result_a)

    # Letter B
    result_b = (5*u) + (3*v) - (4*w)
    print("Letter B - 5𝐮+3v-4w: ", result_b)

    # Letter C
    print("Letter C - u.v = ", u.dot(v))
    print("Letter C - v.w = ", v.dot(w))
    print("Letter C - u.w = ", u.dot(w))

    # Letter D
    print("Letter D - ||u||: ", np.sqrt(u.dot(u)))
    print("Letter D - ||v||: ", np.sqrt(v.dot(v)))
    print("Letter D - ||w||: ", np.sqrt(w.dot(w)))

    # Letter E
    angle_uv = u.dot(v) / (np.linalg.norm(u) * np.linalg.norm(v))
    print("Letter E - angle(u, v):", angle_uv)

    # Letter F
    angle_vw = v.dot(w) / (np.linalg.norm(v) * np.linalg.norm(w))
    print("Letter F - angle(v, w):", angle_vw)

    # Letter G
    angle_uw = u.dot(w) / (np.linalg.norm(u) * np.linalg.norm(w))
    print("Letter G - angle(u, w):", angle_uw)

    # Letter H
    print("Letter H - d(u, v): ", np.linalg.norm(u - v))

    # Letter I
    print("Letter I - d(w, v): ", np.linalg.norm(w - v))

    # Letter J
    print("Letter J - d(u, w): ", np.linalg.norm(u - w))

    # Letter K
    proj_uv = u.dot(v) * v / (np.linalg.norm(v) ** 2)
    print("Letter K - proj(u, v): ", proj_uv)

    # Letter L
    proj_wv = w.dot(v) * v / (np.linalg.norm(v) ** 2)
    print("Letter L - proj(w, v): ", proj_wv)

    # Letter M
    proj_uw = u.dot(w) * w / (np.linalg.norm(w) ** 2)
    print("Letter M - proj(u, w): ", proj_uw)

# Call the function
perform_operations()
# Out:
# Letter A - 3𝐮-2v:  [ -1   7 -22]
# Letter B - 5𝐮+3v-4w:  [ -1  26 -29]
# Letter C - u.v =  -15
# Letter C - v.w =  34
# Letter C - u.w =  -27
# Letter D - ||u||:  5.0990195135927845
# Letter D - ||v||:  5.477225575051661
# Letter D - ||w||:  7.0
# Letter E - angle(u, v): -0.5370861555295747
# Letter F - angle(v, w): 0.8867889026274118
# Letter G - angle(u, w): -0.7564479498187099
# Letter H - d(u, v):  9.273618495495704
# Letter I - d(w, v):  3.3166247903554
# Letter J - d(u, w):  11.357816691600547
# Letter K - proj(u, v):  [-1.  -0.5 -2.5]
# Letter L - proj(w, v):  [2.26666667 1.13333333 5.66666667]
# Letter M - proj(u, w):  [-1.65306122  1.10204082 -3.30612245]

# %% [markdown]
# 3. Let $\textbf{u} = (2,-5,4,6,-3)$, $\textbf{v} = (5,-2,1,-7,-4)$, and $\textbf{w} = (2,1,-3)$ find:<br>
# a. $4\textbf{u}-3\textbf{v}$<br>
# b. $5\textbf{u}+2\textbf{v}-2\textbf{w}$<br>
# c. $\textbf{u} \cdotp \textbf{v}$,$\textbf{v} \cdotp \textbf{w}$, $\textbf{u} \cdotp \textbf{w}$<br>
# d. ||$\textbf{u}$||, ||$\textbf{v}$||, ||$\textbf{w}$||<br>
# e. If $\theta$ is the angle between $\textbf{u}$  and   $\textbf{v}$, find $\cos{\theta}$.<br>
# f. If $\alpha$ is the angle between $\textbf{v}$  and   $\textbf{w}$, find $\cos{\alpha}$.<br>
# g. If $\beta$ is the angle between $\textbf{u}$  and   $\textbf{w}$, find $\cos{\beta}$.<br>
# h. Find $d(\textbf{u},\textbf{v})$.<br>
# i. Find $d(\textbf{w},\textbf{v})$.<br>
# j. Find $d(\textbf{u},\textbf{w})$. <br>
# k. Find $proj(\textbf{u},\textbf{v})$.<br>
# l. Find $proj(\textbf{w},\textbf{v})$.<br>
# m. Find $proj(\textbf{u},\textbf{w})$. <br>
# <br>
# <br>

# %%
import numpy as np

def perform_operations():
    u = np.array([2, -5, 4, 6, -3])
    v = np.array([5, -2, 1, -7, -4])
    w = np.array([2, 1, -3, 0, 0])

    # Letter A
    result_a = (4*u) - (3*v)
    print("Letter A - 4𝐮-3v: ", result_a)

    # Letter B
    result_b = (5*u) + (2*v) - (2*w)
    print("Letter B - 5𝐮+2v-2w: ", result_b)

    # Letter C
    print("Letter C - u.v = ", u.dot(v))
    print("Letter C - v.w = ", v.dot(w))
    print("Letter C - u.w = ", u.dot(w))

    # Letter D
    print("Letter D - ||u||: ", np.sqrt(u.dot(u)))
    print("Letter D - ||v||: ", np.sqrt(v.dot(v)))
    print("Letter D - ||w||: ", np.sqrt(w.dot(w)))

    # Letter E
    angle_uv = u.dot(v) / (np.linalg.norm(u) * np.linalg.norm(v))
    print("Letter E - angle(u, v):", angle_uv)

    # Letter F
    angle_vw = v.dot(w) / (np.linalg.norm(v) * np.linalg.norm(w))
    print("Letter F - angle(v, w):", angle_vw)

    # Letter G
    angle_uw = u.dot(w) / (np.linalg.norm(u) * np.linalg.norm(w))
    print("Letter G - angle(u, w):", angle_uw)

    # Letter H
    print("Letter H - d(u, v): ", np.linalg.norm(u - v))

    # Letter I
    print("Letter I - d(w, v): ", np.linalg.norm(w - v))

    # Letter J
    print("Letter J - d(u, w): ", np.linalg.norm(u - w))

    # Letter K
    proj_uv = u.dot(v) * v / (np.linalg.norm(v) ** 2)
    print("Letter K - proj(u, v): ", proj_uv)

    # Letter L
    proj_wv = w.dot(v) * v / (np.linalg.norm(v) ** 2)
    print("Letter L - proj(w, v): ", proj_wv)

    # Letter M
    proj_uw = u.dot(w) * w / (np.linalg.norm(w) ** 2)
    print("Letter M - proj(u, w): ", proj_uw)

# Call the function
perform_operations()
# Out:
# Letter A - 4𝐮-3v:  [ -7 -14  13  45   0]
# Letter B - 5𝐮+2v-2w:  [ 16 -31  28  16 -23]
# Letter C - u.v =  -6
# Letter C - v.w =  5
# Letter C - u.w =  -13
# Letter D - ||u||:  9.486832980505138
# Letter D - ||v||:  9.746794344808963
# Letter D - ||w||:  3.7416573867739413
# Letter E - angle(u, v): -0.06488856845230502
# Letter F - angle(v, w): 0.13710212427677046
# Letter G - angle(u, w): -0.3662335103823572
# Letter H - d(u, v):  14.035668847618199
# Letter I - d(w, v):  9.9498743710662
# Letter J - d(u, w):  11.40175425099138
# Letter K - proj(u, v):  [-0.31578947  0.12631579 -0.06315789  0.44210526  0.25263158]
# Letter L - proj(w, v):  [ 0.26315789 -0.10526316  0.05263158 -0.36842105 -0.21052632]
# Letter M - proj(u, w):  [-1.85714286 -0.92857143  2.78571429  0.          0.        ]

# %% [markdown]
# 4. Normalize each vector:<br>
# a. $\textbf{u}$ = (5,-7).<br>
# b. $\textbf{v}$ = (1,2,-2,4).<br>
# c. $\textbf{w} = (\frac{1}{2},\frac{-1}{3},\frac{3}{4})$.<br>
# <br>
# <br>

# %%
import numpy as np

def perform_operations():
    # Letter A
    u = np.array([5, -7])
    print('Letter A - ||u||: ', np.sqrt(u.dot(u)))

    # Letter B
    v = np.array([1, 2, -2, 4])
    print('Letter B - ||v||: ', np.sqrt(v.dot(v)))

    # Letter C
    w = np.array([1/2, -1/3, 3/4])
    print('Letter C - ||w||: ', np.sqrt(w.dot(w)))

# Call the function
perform_operations()
# Out:
# Letter A - ||u||:  8.602325267042627
# Letter B - ||v||:  5.0
# Letter C - ||w||:  0.961046882889233

# %% [markdown]
# 5. Let $\textbf{u} = (1,2,-2)$,$\textbf{v} = (3,-12,4)$ and a scalar $k = -3$: <br>
# Find $||u||, ||v||, ||u+v||, ||ku||$.<br>
# <br>
# <br>

# %%
import numpy as np

def perform_operations():
    u = np.array([1, 2, -2])
    v = np.array([3, -12, 4])
    k = -3
    l = k * u
    w = u + v

    print('||u||: ', np.sqrt(u.dot(u)))
    print('||v||: ', np.sqrt(v.dot(v)))
    print('||u+v||: ', np.sqrt(w.dot(w)))
    print('||ku||: ', np.sqrt(l.dot(l)))

# Call the function
perform_operations()
# Out:
# ||u||:  3.0
# ||v||:  13.0
# ||u+v||:  10.954451150103322
# ||ku||:  9.0

# %% [markdown]
# 6. Find k so that $\textbf{u}  \ and \  \textbf{v}$ are orthogonal.
# a. $\textbf{u} = (3, k, -2), \textbf{v} = (6, -4, -3)$.<br>
# b. $\textbf{u} = (5,k,-4,2), \textbf{v} = (1,-3,2,2k)$.<br>
# c. $\textbf{u} = (1,7,k+2,-2), \textbf{v} = (3, k, -3,k)$.<br>

# %% [raw]
# No Pythonic Solution
